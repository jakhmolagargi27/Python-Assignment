# %% [markdown]
# <a href="https://colab.research.google.com/github/jakhmolagargi27/Python-Assignment/blob/main/Gargi_Jakhmola_CPDA_B7A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+7
# Out:
# 9
